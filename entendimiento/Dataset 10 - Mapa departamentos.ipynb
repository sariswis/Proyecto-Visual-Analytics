# %% [markdown]
# # Entendimiento GeoJSONs

# %% [markdown]
# ## Departamentos
#
# **Nombre de archivo:** departamentos.geojson

# %% [markdown]
# Incluye los 32 departamentos, incluyendo el Distrito Capital de Bogotá
#
# ![Dptos](assets/Dptos.png)

# %% [markdown]
# Cada ítem tiene el código (DPTO_CCDGO), el nombre (DPTO_CNMBR), la versión, información geográfica y otros datos de TerriData
#
# ![Dptos](assets/Items-Dptos.png)
