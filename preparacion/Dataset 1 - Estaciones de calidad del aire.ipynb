# %% [markdown]
# # Preparación de datos
#
# **Conjunto de datos:** Dataset 1 - Estaciones de calidad del aire
#
# **Nombre de archivo:** air_quality_stations.csv

# %% [markdown]
# ## 0. Inicialización

# %% [markdown]
# Instalar ydata-profiling

# %%
# !pip install ydata-profiling

# %% [markdown]
# Importaciones

# %%
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
import seaborn as sns

import folium
import json
from tabulate import tabulate

# %% [markdown]
# Visualización de tablas y gráficas

# %%
sns.set_style("darkgrid")

def print_table(df):
    print(tabulate(df, headers='keys', tablefmt='simple_outline'))

# %% [markdown]
# Lectura y muestra del archivo

# %%
df = pd.read_csv('../data/original/air_quality_stations.csv')
df.head()
# Out:
#    id state  latitude  longitude
# 0   8   ACT  4.530214 -74.142217
# 1  18   ACT  4.940316 -73.970698
# 2  20   ACT  5.200000 -73.883000
# 3   4   ACT  4.596229 -74.194715
# 4   6   ACT  4.695702 -74.215583

# %% [markdown]
# **1.** Eliminar columnas innecesarias

# %%
df = df.drop(columns=['state'])

# %% [markdown]
# **2.** Ordenar por ID

# %%
df.sort_values(by='id', inplace=True)

# %% [markdown]
# Resultado final

# %%
df
# Out:
#     id  latitude  longitude
# 18   1  5.129059 -73.895885
# 17   2  4.733274 -74.266156
# 10   3  4.584585 -74.219878
# 3    4  4.596229 -74.194715
# 22   5  4.525167 -74.243535
# 4    6  4.695702 -74.215583
# 12   7  4.719539 -73.968738
# 0    8  4.530214 -74.142217
# 15   9  5.066150 -73.878100
# 11  10  5.010013 -74.002743
# 21  11  5.540477 -73.632574
# 14  12  5.054945 -73.976986
# 16  13  4.939167 -74.010833
# 8   14  4.716525 -74.211712
# 19  15  4.976390 -73.970698
# 6   16  4.298055 -74.819167
# 5   17  4.862871 -74.056341
# 1   18  4.940316 -73.970698
# 13  19  4.721387 -74.236610
# 2   20  5.200000 -73.883000
# 20  21  5.537028 -73.635303
# 9   22  4.809444 -74.102500
# 7   23  4.594991 -74.204826

# %%
reporte = ProfileReport(df)
reporte.to_file("archivos_generados/Reporte perfilamiento - Dataset 1 Final.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Exportar a CSV

# %%
df.to_csv('../data/preparada/stations.csv', index=False)
